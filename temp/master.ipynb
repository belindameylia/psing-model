# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dython.nominal import associations
import numpy as np
from scipy.stats import pearsonr

# Read file dataset from CSV
data = pd.read_csv("Survei Pengguna Produk Simpanan Individu.csv")

# Data detail
print(data.info())
print(data.describe(include='all'))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 21 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                                                                                     444 non-null    object
#  1   Kami mohon kesediaan Anda untuk menjawab pertanyaan-pertanyaan pada section berikutnya dengan jujur dan sesuai dengan produk simpanan individu yang Anda miliki. Dengan lanjut ke section berikutnya, Anda menyetujui bahwa seluruh data (terkecuali nama dan nomor telepon undian) akan digunakan sebagai bahan penelitian.  444 non-null    object
#  2   Produk simpanan individu apa yang Anda gunakan?                                                                                                                                                                                                                                                                               444 non-null    object
#  3   Nama / Inisial                                                                                                                                                                                                                                                                                                                365 non-null    object
#  4   Nomor Telepon - GOPAY/OVO/SHOPEEPAY                                                                                                                                                                                                                                                                                           355 non-null    object
#  5   Umur                                                                                                                                                                                                                                                                                                                          444 non-null    object
#  6   Domisili                                                                                                                                                                                                                                                                                                                      444 non-null    object
#  7   Gender                                                                                                                                                                                                                                                                                                                        444 non-null    object
#  8   Status Perkawinan                                                                                                                                                                                                                                                                                                             444 non-null    object
#  9   Jumlah Tanggungan                                                                                                                                                                                                                                                                                                             444 non-null    object
#  10  Kegiatan atau pekerjaan saat ini                                                                                                                                                                                                                                                                                              444 non-null    object
#  11  Apa tujuan pengunaan produk simpanan individu yang Anda pilih?                                                                                                                                                                                                                                                                444 non-null    object
#  12  Berapa jumlah rata-rata penghasilan Anda per bulan?                                                                                                                                                                                                                                                                           444 non-null    object
#  13  Seberapa besar rata-rata persentase penghasilan yang Anda tabung?                                                                                                                                                                                                                                                             444 non-null    object
#  14  Menurut Anda, apakah produk simpanan individu yang Anda gunakan saat ini memiliki fungsionalitas yang baik?                                                                                                                                                                                                                   444 non-null    int64
#  15  Menurut Anda, apakah produk simpanan individu yang Anda gunakan memiliki biaya admin yang sesuai dengan fungsi yang Anda dapatkan?                                                                                                                                                                                            444 non-null    int64
#  16  Menurut Anda, apakah produk simpanan individu yang anda gunakan memiliki limit tabungan yang sesuai dengan kebutuhan Anda?                                                                                                                                                                                                    444 non-null    int64
#  17  Menurut Anda, apakah produk simpanan individu yang Anda gunakan memiliki bunga tabungan yang sesuai dengan keinginan Anda?                                                                                                                                                                                                    444 non-null    int64
#  18  Menurut Anda, apakah produk simpanan individu yang Anda gunakan saat ini memiliki syarat setoran awal yang memberatkan?                                                                                                                                                                                                       444 non-null    int64
#  19  Apakah produk simpanan individu yang Anda gunakan sudah sesuai dan cocok dengan kebutuhan, kemampuan, dan keinginan Anda?                                                                                                                                                                                                     444 non-null    int64
#  20  Apakah ada alasan lain di luar bunga, limit, dan biaya admin yang membuat Anda memutuskan untuk menggunakan produk simpanan individu tersebut?                                                                                                                                                                                251 non-null    object
# dtypes: int64(6), object(15)
# memory usage: 73.0+ KB
# None
#                   Timestamp  \
# count                   444
# unique                  444
# top     15/12/2024 18:43:03
# freq                      1
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
#        Kami mohon kesediaan Anda untuk menjawab pertanyaan-pertanyaan pada section berikutnya dengan jujur dan sesuai dengan produk simpanan individu yang Anda miliki. Dengan lanjut ke section berikutnya, Anda menyetujui bahwa seluruh data (terkecuali nama dan nomor telepon undian) akan digunakan sebagai bahan penelitian.  \
# count                                                 444
# unique                                                  1
# top                       Setuju dan saya bersedia lanjut
# freq                                                  444
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Produk simpanan individu apa yang Anda gunakan? Nama / Inisial  \
# count                                              444            365
# unique                                               9            340
# top                                   Tabungan Regular              -
# freq                                               274              5
# mean                                               NaN            NaN
# std                                                NaN            NaN
# min                                                NaN            NaN
# 25%                                                NaN            NaN
# 50%                                                NaN            NaN
# 75%                                                NaN            NaN
# max                                                NaN            NaN
#
#        Nomor Telepon - GOPAY/OVO/SHOPEEPAY         Umur     Domisili  \
# count                                  355          444          444
# unique                                 338            5            2
# top                                      -  21-30 tahun  Jabodetabek
# freq                                    11          204          315
# mean                                   NaN          NaN          NaN
# std                                    NaN          NaN          NaN
# min                                    NaN          NaN          NaN
# 25%                                    NaN          NaN          NaN
# 50%                                    NaN          NaN          NaN
# 75%                                    NaN          NaN          NaN
# max                                    NaN          NaN          NaN
#
#            Gender Status Perkawinan Jumlah Tanggungan  ...  \
# count         444               444               444  ...
# unique          2                 2                 5  ...
# top     Perempuan       Belum Kawin            0 jiwa  ...
# freq          237               386               348  ...
# mean          NaN               NaN               NaN  ...
# std           NaN               NaN               NaN  ...
# min           NaN               NaN               NaN  ...
# 25%           NaN               NaN               NaN  ...
# 50%           NaN               NaN               NaN  ...
# 75%           NaN               NaN               NaN  ...
# max           NaN               NaN               NaN  ...
#
#        Apa tujuan pengunaan produk simpanan individu yang Anda pilih?  \
# count                                                 444
# unique                                                 13
# top                                  Kegiatan sehari-hari
# freq                                                  172
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Berapa jumlah rata-rata penghasilan Anda per bulan?  \
# count                                                 444
# unique                                                  6
# top                                             5-10 juta
# freq                                                  153
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Seberapa besar rata-rata persentase penghasilan yang Anda tabung?  \
# count                                                 444
# unique                                                  6
# top                                                 > 30%
# freq                                                  121
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Menurut Anda, apakah produk simpanan individu yang Anda gunakan saat ini memiliki fungsionalitas yang baik?  \
# count                                          444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.486486
# std                                              0.621145
# min                                              1.000000
# 25%                                              3.000000
# 50%                                              4.000000
# 75%                                              4.000000
# max                                              4.000000
#
#         Menurut Anda, apakah produk simpanan individu yang Anda gunakan memiliki biaya admin yang sesuai dengan fungsi yang Anda dapatkan?  \
# count                                          444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.227477
# std                                              0.795054
# min                                              1.000000
# 25%                                              3.000000
# 50%                                              3.000000
# 75%                                              4.000000
# max                                              4.000000
#
#         Menurut Anda, apakah produk simpanan individu yang anda gunakan memiliki limit tabungan yang sesuai dengan kebutuhan Anda?  \
# count                                          444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.490991
# std                                              0.670171
# min                                              1.000000
# 25%                                              3.000000
# 50%                                              4.000000
# 75%                                              4.000000
# max                                              4.000000
#
#         Menurut Anda, apakah produk simpanan individu yang Anda gunakan memiliki bunga tabungan yang sesuai dengan keinginan Anda?  \
# count                                          444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             2.817568
# std                                              0.943342
# min                                              1.000000
# 25%                                              2.000000
# 50%                                              3.000000
# 75%                                              4.000000
# max                                              4.000000
#
#         Menurut Anda, apakah produk simpanan individu yang Anda gunakan saat ini memiliki syarat setoran awal yang memberatkan?  \
# count                                          444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             1.781532
# std                                              0.982704
# min                                              1.000000
# 25%                                              1.000000
# 50%                                              1.000000
# 75%                                              2.000000
# max                                              4.000000
#
#         Apakah produk simpanan individu yang Anda gunakan sudah sesuai dan cocok dengan kebutuhan, kemampuan, dan keinginan Anda?  \
# count                                          444.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             3.414414
# std                                              0.592938
# min                                              1.000000
# 25%                                              3.000000
# 50%                                              3.000000
# 75%                                              4.000000
# max                                              4.000000
#
#         Apakah ada alasan lain di luar bunga, limit, dan biaya admin yang membuat Anda memutuskan untuk menggunakan produk simpanan individu tersebut?
# count                                                 251
# unique                                                181
# top                                                     -
# freq                                                   24
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# [11 rows x 21 columns]
# (444, 21)

# %%
data.rename(columns = {
    "Timestamp":"jejak waktu",
    "Kami mohon kesediaan Anda untuk menjawab pertanyaan-pertanyaan pada section berikutnya dengan jujur dan sesuai dengan produk simpanan individu yang Anda miliki. Dengan lanjut ke section berikutnya, Anda menyetujui bahwa seluruh data (terkecuali nama dan nomor telepon undian) akan digunakan sebagai bahan penelitian.":"perizinan",
    "Produk simpanan individu apa yang Anda gunakan?":"produk",
    "Nama / Inisial":"nama",
    "Nomor Telepon - GOPAY/OVO/SHOPEEPAY":"nomor_telepon",
    "Umur":"umur",
    "Domisili":"domisili",
    "Gender":"gender",
    "Status Perkawinan":"status_perkawinan",
    "Jumlah Tanggungan":"jumlah_tanggungan",
    "Kegiatan atau pekerjaan saat ini":"profesi",
    "Apa tujuan pengunaan produk simpanan individu yang Anda pilih?":"tujuan",
    "Berapa jumlah rata-rata penghasilan Anda per bulan?":"penghasilan",
    "Seberapa besar rata-rata persentase penghasilan yang Anda tabung?":"persentasi_tabungan",
    "Menurut Anda, apakah produk simpanan individu yang Anda gunakan saat ini memiliki fungsionalitas yang baik?":"rate_fungsionalitas",
    "Menurut Anda, apakah produk simpanan individu yang Anda gunakan memiliki biaya admin yang sesuai dengan fungsi yang Anda dapatkan?":"rate_admin",
    "Menurut Anda, apakah produk simpanan individu yang anda gunakan memiliki limit tabungan yang sesuai dengan kebutuhan Anda?":"rate_limit",
    "Menurut Anda, apakah produk simpanan individu yang Anda gunakan memiliki bunga tabungan yang sesuai dengan keinginan Anda?":"rate_bunga",
    "Menurut Anda, apakah produk simpanan individu yang Anda gunakan saat ini memiliki syarat setoran awal yang memberatkan?":"rate_setoran_awal",
    "Apakah produk simpanan individu yang Anda gunakan sudah sesuai dan cocok dengan kebutuhan, kemampuan, dan keinginan Anda?":"rate_kebutuhan",
    "Apakah ada alasan lain di luar bunga, limit, dan biaya admin yang membuat Anda memutuskan untuk menggunakan produk simpanan individu tersebut?":"alasan_lainnya"
    }, 
            inplace = True)

print(data)
# Out:
#              jejak waktu                        perizinan              produk  \
# 0       12/11/2024 16:35  Setuju dan saya bersedia lanjut  Tabungan Anak Muda
# 1    13/11/2024 07:03:59  Setuju dan saya bersedia lanjut    Tabungan Regular
# 2    13/11/2024 07:08:22  Setuju dan saya bersedia lanjut    Tabungan Regular
# 3    13/11/2024 07:15:44  Setuju dan saya bersedia lanjut    Tabungan Regular
# 4    13/11/2024 07:18:27  Setuju dan saya bersedia lanjut    Tabungan Regular
# ..                   ...                              ...                 ...
# 439      5/12/2024 10:54  Setuju dan saya bersedia lanjut    Tabungan Regular
# 440      6/12/2024 18:11  Setuju dan saya bersedia lanjut  Tabungan Anak Muda
# 441      7/12/2024 23:47  Setuju dan saya bersedia lanjut    Tabungan Regular
# 442      9/12/2024 18:16  Setuju dan saya bersedia lanjut    Tabungan Regular
# 443  15/12/2024 18:43:03  Setuju dan saya bersedia lanjut  Tabungan Anak Muda
#
#                       nama         nomor_telepon         umur     domisili  \
# 0                      BLM                   NaN  21-30 tahun  Jabodetabek
# 1            Javier Justin  087783368448 - GOPAY  17-21 tahun  Jabodetabek
# 2                      DVM                   NaN  21-30 tahun  Jabodetabek
# 3                      SET           81804544311  17-21 tahun  Jabodetabek
# 4                      RBT            8128722384  30-55 tahun  Jabodetabek
# ..                     ...                   ...          ...          ...
# 439  Levi Valent Christian                   NaN  21-30 tahun  Jabodetabek
# 440                      J           81316537930  21-30 tahun  Jabodetabek
# 441                      Y    082114792841 - OVO  21-30 tahun  Jabodetabek
# 442                     jh    081270884988 - ovo  17-21 tahun  Jabodetabek
# 443                    GDN    082140035302 - OVO  21-30 tahun  Jabodetabek
#
#         gender status_perkawinan jumlah_tanggungan  ...  \
# 0    Perempuan       Belum Kawin            0 jiwa  ...
# 1    Laki-laki       Belum Kawin            0 jiwa  ...
# 2    Laki-laki       Belum Kawin            0 jiwa  ...
# 3    Laki-laki       Belum Kawin            0 jiwa  ...
# 4    Laki-laki             Kawin            1 jiwa  ...
# ..         ...               ...               ...  ...
# 439  Laki-laki       Belum Kawin            0 jiwa  ...
# 440  Laki-laki       Belum Kawin            0 jiwa  ...
# 441  Perempuan       Belum Kawin            0 jiwa  ...
# 442  Perempuan       Belum Kawin            0 jiwa  ...
# 443  Perempuan       Belum Kawin            0 jiwa  ...
#
#                                                 tujuan penghasilan  \
# 0        Simpanan jangka panjang, Kegiatan sehari-hari   5-10 juta
# 1                                 Kegiatan sehari-hari   5-10 juta
# 2                                 Kegiatan sehari-hari  10-15 juta
# 3                   Investasi, Simpanan jangka panjang    1-5 juta
# 4                                 Kegiatan sehari-hari   > 20 juta
# ..                                                 ...         ...
# 439  Investasi, Simpanan jangka panjang, Kegiatan s...   5-10 juta
# 440                               Kegiatan sehari-hari    1-5 juta
# 441                               Kegiatan sehari-hari   5-10 juta
# 442                               Kegiatan sehari-hari   5-10 juta
# 443                               Kegiatan sehari-hari   5-10 juta
#
#     persentasi_tabungan rate_fungsionalitas  rate_admin  rate_limit  \
# 0                20-30%                   3           4           4
# 1                 > 30%                   3           2           3
# 2                 > 30%                   4           3           4
# 3                10-20%                   3           3           3
# 4                20-30%                   4           3           4
# ..                  ...                 ...         ...         ...
# 439              10-20%                   3           3           4
# 440                1-5%                   3           3           3
# 441              20-30%                   4           4           4
# 442              20-30%                   3           3           3
# 443               > 30%                   3           3           3
#
#      rate_bunga  rate_setoran_awal  rate_kebutuhan  \
# 0             3                  1               3
# 1             2                  2               3
# 2             3                  1               4
# 3             2                  1               3
# 4             3                  1               3
# ..          ...                ...             ...
# 439           4                  2               3
# 440           3                  1               4
# 441           4                  3               3
# 442           2                  1               3
# 443           3                  3               3
#
#                                         alasan_lainnya
# 0                                                    -
# 1                                             Praktis
# 2    Integritas dan nama baik perusahaan tersebut s...
# 3                                                  NaN
# 4    Bebas biaya admin untuk transfer antar bank da...
# ..                                                 ...
# 439                                                NaN
# 440                                                NaN
# 441                                                  -
# 442                                                NaN
# 443     Sebagai persyaratan untuk pendaftaran beasiswa
#
# [444 rows x 21 columns]

# %% [markdown]
# Handle Missing Value

# %%
# Cek missing value kolom
print(data.isnull().sum())

print("\n ---Visualization---")

# DataFrame untuk menghitung missing values
missing_values = pd.DataFrame({
    'Attributes': data.columns,  # Nama kolom
    'Frequency': data.isnull().sum()  # Jumlah missing values di setiap kolom
})

# Urutkan berdasarkan jumlah missing value
missing_values = missing_values.sort_values(by='Frequency', ascending=False)

# Plot visualisasi
plt.figure(figsize=(20, 10))  # Ukuran grafik
plt.title('Missing Values', fontsize=20, fontweight='bold')  # Judul grafik

sns.barplot(
    x='Attributes',
    y='Frequency',
    data=missing_values,
    order=missing_values['Attributes']
)

# Rotasi label untuk kolom agar lebih mudah dibaca
plt.xticks(rotation=45, ha='right')

# Tampilkan grafik
plt.tight_layout()  # Atur layout agar tidak terpotong
plt.show()
# Out:
# jejak waktu              0
# perizinan                0
# produk                   0
# nama                    79
# nomor_telepon           89
# umur                     0
# domisili                 0
# gender                   0
# status_perkawinan        0
# jumlah_tanggungan        0
# profesi                  0
# tujuan                   0
# penghasilan              0
# persentasi_tabungan      0
# rate_fungsionalitas      0
# rate_admin               0
# rate_limit               0
# rate_bunga               0
# rate_setoran_awal        0
# rate_kebutuhan           0
# alasan_lainnya         193
# dtype: int64
#
#  ---Visualization---

# %%
# Hapus data by label
data.dropna(subset=['produk'], inplace=True)


# Cek missing value
print(data.isnull().sum())
# Out:
# jejak waktu              0
# perizinan                0
# produk                   0
# nama                    79
# nomor_telepon           89
# umur                     0
# domisili                 0
# gender                   0
# status_perkawinan        0
# jumlah_tanggungan        0
# profesi                  0
# tujuan                   0
# penghasilan              0
# persentasi_tabungan      0
# rate_fungsionalitas      0
# rate_admin               0
# rate_limit               0
# rate_bunga               0
# rate_setoran_awal        0
# rate_kebutuhan           0
# alasan_lainnya         193
# dtype: int64

# %% [markdown]
# Remove Irrelevant Attributes

# %%
correlations = associations(data)
corr = correlations['corr']
# Out:
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(
# C:\Users\bcamaster\AppData\Roaming\Python\Python310\site-packages\dython\nominal.py:176: RuntimeWarning: Unable to calculate Cramer's V using bias correction. Consider using bias_correction=False (or cramers_v_bias_correction=False if calling from associations)
#   warnings.warn(

# %%
# tampilin nilai corr mat by label
print(corr['produk'])
# Out:
# jejak waktu            0.000000
# perizinan              0.000000
# produk                 1.000000
# nama                   0.000000
# nomor_telepon          0.000000
# umur                   0.063552
# domisili               0.045980
# gender                 0.060298
# status_perkawinan      0.110882
# jumlah_tanggungan      0.000000
# profesi                0.170219
# tujuan                 0.248651
# penghasilan            0.158232
# persentasi_tabungan    0.067812
# rate_fungsionalitas    0.112885
# rate_admin             0.110241
# rate_limit             0.111841
# rate_bunga             0.201152
# rate_setoran_awal      0.148419
# rate_kebutuhan         0.162613
# alasan_lainnya         0.265433
# Name: produk, dtype: float64

# %%
irrelevant_attributes = corr['produk'][corr['produk'] < 0.05].keys()
print("Kolom yang akan dihapus:", irrelevant_attributes)

# Hapus kolom dengan korelasi < 0.05
for item in irrelevant_attributes:
    # Hapus kolom dengan nama yang ada di variabel `item`
    data.drop([item], axis=1, inplace=True)

print(data.columns)
# Out:
# Kolom yang akan dihapus: Index(['jejak waktu', 'perizinan', 'nama', 'nomor_telepon', 'domisili',
#        'jumlah_tanggungan'],
#       dtype='object')
# Index(['produk', 'umur', 'gender', 'status_perkawinan', 'profesi', 'tujuan',
#        'penghasilan', 'persentasi_tabungan', 'rate_fungsionalitas',
#        'rate_admin', 'rate_limit', 'rate_bunga', 'rate_setoran_awal',
#        'rate_kebutuhan', 'alasan_lainnya'],
#       dtype='object')

# %% [markdown]
# Handling duplicated data

# %%
print("Data sebelum dihapus duplikat:\n", data)

# Menghapus duplikat
data = data.drop_duplicates()

print("\nData setelah dihapus duplikat:\n", data)
# Out:
# Data sebelum dihapus duplikat:
#                   produk         umur     gender status_perkawinan  \
# 0    Tabungan Anak Muda  21-30 tahun  Perempuan       Belum Kawin
# 1      Tabungan Regular  17-21 tahun  Laki-laki       Belum Kawin
# 2      Tabungan Regular  21-30 tahun  Laki-laki       Belum Kawin
# 3      Tabungan Regular  17-21 tahun  Laki-laki       Belum Kawin
# 4      Tabungan Regular  30-55 tahun  Laki-laki             Kawin
# ..                  ...          ...        ...               ...
# 439    Tabungan Regular  21-30 tahun  Laki-laki       Belum Kawin
# 440  Tabungan Anak Muda  21-30 tahun  Laki-laki       Belum Kawin
# 441    Tabungan Regular  21-30 tahun  Perempuan       Belum Kawin
# 442    Tabungan Regular  17-21 tahun  Perempuan       Belum Kawin
# 443  Tabungan Anak Muda  21-30 tahun  Perempuan       Belum Kawin
#
#              profesi                                             tujuan  \
# 0    Karyawan Swasta      Simpanan jangka panjang, Kegiatan sehari-hari
# 1          Mahasiswa                               Kegiatan sehari-hari
# 2    Karyawan Swasta                               Kegiatan sehari-hari
# 3          Mahasiswa                 Investasi, Simpanan jangka panjang
# 4    Karyawan Swasta                               Kegiatan sehari-hari
# ..               ...                                                ...
# 439  Karyawan Swasta  Investasi, Simpanan jangka panjang, Kegiatan s...
# 440          Lainnya                               Kegiatan sehari-hari
# 441  Karyawan Swasta                               Kegiatan sehari-hari
# 442  Karyawan Swasta                               Kegiatan sehari-hari
# 443  Karyawan Swasta                               Kegiatan sehari-hari
#
#     penghasilan persentasi_tabungan  rate_fungsionalitas  rate_admin  \
# 0     5-10 juta              20-30%                    3           4
# 1     5-10 juta               > 30%                    3           2
# 2    10-15 juta               > 30%                    4           3
# 3      1-5 juta              10-20%                    3           3
# 4     > 20 juta              20-30%                    4           3
# ..          ...                 ...                  ...         ...
# 439   5-10 juta              10-20%                    3           3
# 440    1-5 juta                1-5%                    3           3
# 441   5-10 juta              20-30%                    4           4
# 442   5-10 juta              20-30%                    3           3
# 443   5-10 juta               > 30%                    3           3
#
#      rate_limit  rate_bunga  rate_setoran_awal  rate_kebutuhan  \
# 0             4           3                  1               3
# 1             3           2                  2               3
# 2             4           3                  1               4
# 3             3           2                  1               3
# 4             4           3                  1               3
# ..          ...         ...                ...             ...
# 439           4           4                  2               3
# 440           3           3                  1               4
# 441           4           4                  3               3
# 442           3           2                  1               3
# 443           3           3                  3               3
#
#                                         alasan_lainnya
# 0                                                    -
# 1                                             Praktis
# 2    Integritas dan nama baik perusahaan tersebut s...
# 3                                                  NaN
# 4    Bebas biaya admin untuk transfer antar bank da...
# ..                                                 ...
# 439                                                NaN
# 440                                                NaN
# 441                                                  -
# 442                                                NaN
# 443     Sebagai persyaratan untuk pendaftaran beasiswa
#
# [444 rows x 15 columns]
#
# Data setelah dihapus duplikat:
#                   produk         umur     gender status_perkawinan  \
# 0    Tabungan Anak Muda  21-30 tahun  Perempuan       Belum Kawin
# 1      Tabungan Regular  17-21 tahun  Laki-laki       Belum Kawin
# 2      Tabungan Regular  21-30 tahun  Laki-laki       Belum Kawin
# 3      Tabungan Regular  17-21 tahun  Laki-laki       Belum Kawin
# 4      Tabungan Regular  30-55 tahun  Laki-laki             Kawin
# ..                  ...          ...        ...               ...
# 439    Tabungan Regular  21-30 tahun  Laki-laki       Belum Kawin
# 440  Tabungan Anak Muda  21-30 tahun  Laki-laki       Belum Kawin
# 441    Tabungan Regular  21-30 tahun  Perempuan       Belum Kawin
# 442    Tabungan Regular  17-21 tahun  Perempuan       Belum Kawin
# 443  Tabungan Anak Muda  21-30 tahun  Perempuan       Belum Kawin
#
#              profesi                                             tujuan  \
# 0    Karyawan Swasta      Simpanan jangka panjang, Kegiatan sehari-hari
# 1          Mahasiswa                               Kegiatan sehari-hari
# 2    Karyawan Swasta                               Kegiatan sehari-hari
# 3          Mahasiswa                 Investasi, Simpanan jangka panjang
# 4    Karyawan Swasta                               Kegiatan sehari-hari
# ..               ...                                                ...
# 439  Karyawan Swasta  Investasi, Simpanan jangka panjang, Kegiatan s...
# 440          Lainnya                               Kegiatan sehari-hari
# 441  Karyawan Swasta                               Kegiatan sehari-hari
# 442  Karyawan Swasta                               Kegiatan sehari-hari
# 443  Karyawan Swasta                               Kegiatan sehari-hari
#
#     penghasilan persentasi_tabungan  rate_fungsionalitas  rate_admin  \
# 0     5-10 juta              20-30%                    3           4
# 1     5-10 juta               > 30%                    3           2
# 2    10-15 juta               > 30%                    4           3
# 3      1-5 juta              10-20%                    3           3
# 4     > 20 juta              20-30%                    4           3
# ..          ...                 ...                  ...         ...
# 439   5-10 juta              10-20%                    3           3
# 440    1-5 juta                1-5%                    3           3
# 441   5-10 juta              20-30%                    4           4
# 442   5-10 juta              20-30%                    3           3
# 443   5-10 juta               > 30%                    3           3
#
#      rate_limit  rate_bunga  rate_setoran_awal  rate_kebutuhan  \
# 0             4           3                  1               3
# 1             3           2                  2               3
# 2             4           3                  1               4
# 3             3           2                  1               3
# 4             4           3                  1               3
# ..          ...         ...                ...             ...
# 439           4           4                  2               3
# 440           3           3                  1               4
# 441           4           4                  3               3
# 442           3           2                  1               3
# 443           3           3                  3               3
#
#                                         alasan_lainnya
# 0                                                    -
# 1                                             Praktis
# 2    Integritas dan nama baik perusahaan tersebut s...
# 3                                                  NaN
# 4    Bebas biaya admin untuk transfer antar bank da...
# ..                                                 ...
# 439                                                NaN
# 440                                                NaN
# 441                                                  -
# 442                                                NaN
# 443     Sebagai persyaratan untuk pendaftaran beasiswa
#
# [443 rows x 15 columns]
